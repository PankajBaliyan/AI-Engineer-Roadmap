# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# to check pandas version
print(pd.__version__)

# Open file
df = pd.read_csv('data.csv')

# Output file
print(df.to_string())
# Out:
# 2.2.3
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
myDataset = {
    "Cars" : ["Rubicon","Thar", "Lamborghini"],
    "Roll_no": [1,2,3]
}
result = pd.DataFrame(myDataset)
print(result)
# Out:
#           Cars  Roll_no
# 0      Rubicon        1
# 1         Thar        2
# 2  Lamborghini        3

# %% [markdown]
# Series
#
# A Pandas Series is like a column in a table.
# It is a one-dimensional array holding data of any type.

# %%
mySeries = [1,2,3,4,5]
result = pd.Series(mySeries)
print(result)

# Get data using label (default label is index, we can modify it)
print(result[0])

# Let's modify index's
result1 = pd.Series(mySeries, index=["x","y","z","a","b"])
print(result1)

# Get value using new index
print(result1['x'])

# Creating series with key/values pair
calories = {"day1": 420, "day2": 380, "day3": 390}
data = {
    "cars" : ["one","two","three"],
"number" : [1,3,5]
}
print(data)

my_var = pd.DataFrame(data)
print(my_var)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# 1
# x    1
# y    2
# z    3
# a    4
# b    5
# dtype: int64
# 1
# {'cars': ['one', 'two', 'three'], 'number': [1, 3, 5]}
#     cars  number
# 0    one       1
# 1    two       3
# 2  three       5

# %% [markdown]
# DataFrames
#
# Data sets in Pandas are usually multi-dimensional tables, called DataFrames.
#
# Series is like a column, a DataFrame is the whole table.

# %%
data = {
    "cars" : ["one","two","three"],
    "number" : [1,3,5]
}

my_var = pd.DataFrame(data)
print(my_var)
# Out:
#     cars  number
# 0    one       1
# 1    two       3
# 2  three       5

# %% [markdown]
# Locate Row
#
# As you can see from the result above, the DataFrame is like a table with rows and columns.
#
# Pandas use the loc attribute to return one or more specified row(s)

# %%
print(my_var.loc[0])
# Out:
# cars      one
# number      1
# Name: 0, dtype: object

# %%
# use a list of indexes:
print(df.loc[[0, 1]])
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0

# %% [markdown]
# Named Indexes
#
# With the index argument, you can name your own indexes.

# %%
data = {"calories": [420, 380, 390], "duration": [50, 40, 45]}

df = pd.DataFrame(data, index=["day1", "day2", "day3"])

print(df)

# refer to the named index:
print(df.loc["day2"])
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45
# calories    380
# duration     40
# Name: day2, dtype: int64

# %% [markdown]
# Load Files Into a DataFrame
#
# If your data sets are stored in a file, Pandas can load them into a DataFrame.

# %%
import pandas as pd

df = pd.read_csv("data.csv")

print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
# print(df.loc[0]) # To get the first row

# To return multiple rows
# print(df.loc[[0,1,2]])

# Return complete dataFrame
# print(df.loc[:])

# DataFrame with named index
# df = pd.DataFrame(data, index = ["Day1", "Day2", "Day3", "Day4", "Day5", "Day6", "Day7", "Day8", "Day9", "Day10"])

# To return a named index
# print(df.loc["Day2"])

# Load files into a DataFrame
# df = pd.read_csv('data.csv')

# To return the first 10 rows
# print(df.head(10))

# head, by default, returns the first 5 rows

# To return the last 5 rows
# print(df.tail())

# To return information about the data
# print(df.info())

# To string the data
# to_string() method is used to render a DataFrame to a console-friendly tabular output.
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
# Inserting JSON data into a DataFrame

# sample data
myJSONData = [
    {
        "name": "John",
        "age": 30,
        "city": "New York"
    },
    {
        "name": "Jane",
        "age": 25,
        "city": "Los Angeles"
    },
    {
        "name": "Bob",
        "age": 35,
        "city": "Chicago"
    }
]

# Load JSON data into a DataFrame
df = pd.DataFrame(myJSONData)

# Print the DataFrame
print(df)
# Out:
#    name  age         city
# 0  John   30     New York
# 1  Jane   25  Los Angeles
# 2   Bob   35      Chicago

# %%
# Insert the correct syntax for loading JSON files into a DataFrame.
df = pd.read_json('data.json')

print(df.to_string())
# Out:
#    name  age         city
# 0  John  300     New York
# 1  Jane   25  Los Angeles
# 2   Bob   35      Chicago

# %%
# Insert the correct syntax for loading a Python dictionary called "data" into a DataFrame.

# The data dictionary is already defined.
data = {
    "name": ["John", "Jane", "Mary", "Bob"],
    "age": [23, 34, 45, 56],
    "city": ["New York", "London", "Paris", "Tokyo"],
}

df = pd.DataFrame(data)
print(df)
# Out:
#    name  age      city
# 0  John   23  New York
# 1  Jane   34    London
# 2  Mary   45     Paris
# 3   Bob   56     Tokyo

# %%
# max_rows
# The number of rows returned is defined in Pandas option settings.

# You can check your system's maximum rows with the pd.options.display.max_rows statement.
print(pd.options.display.max_rows)

# Increase the maximum number of rows to display the entire DataFrame:
pd.options.display.max_rows = 9999

df = pd.read_csv("data.csv")

print(df)
# Out:
# 60
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...
